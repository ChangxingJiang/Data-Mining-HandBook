# %% [markdown]
# # 参数设置

# %%
ACCESS_TOKEN = "24.a2a52efe2d9565985bac1a0164647885.2592000.1594082650.282335-20267153"
ACCESS_TOKEN_2 = "24.441e824929264c84c1d1231938930a4f.2592000.1594437662.282335-20342396"

# %%
import json
import requests
from PIL import Image

# %%
import base64

# %%
DEMO_PATH_1 = "E:/[Github]/CUCBiye/API/demo_1.jpg"
DEMO_PATH_2 = "E:/[Github]/CUCBiye/API/demo_2.jpeg"
DEMO_PATH_3 = "E:/[Github]/CUCBiye/API/demo_3.jpeg"
DEMO_PATH_4 = "E:/[Github]/CUCBiye/API/demo_4.jpg"
DEMO_PATH_5 = "E:/[Github]/CUCBiye/API/demo_5.jpg"
DEMO_PATH_6 = "E:/[Github]/CUCBiye/API/demo_6.jpg"

# %%
def load_file_in_base64(path):
    """
    载入文件并进行Base64编码

    :param path: <str> 文件路径
    :return: <str> Base64编码后的文件
    """
    with open(path, 'rb') as f:
        return str(base64.b64encode(f.read()), encoding='utf-8')

# %%
def face_detect(demo_base64):
    """
    人脸监测和属性分析
    :param demo_base64: <str> BASE64格式的目标图
    :return:
    """
    request_url = "https://aip.baidubce.com/rest/2.0/face/v3/detect"

    params = json.dumps({
        "image": demo_base64,
        "image_type": "BASE64",
        "face_field": "age,beauty,expression,face_shape,gender,glasses,landmark,landmark150,race,quality,eye_status,emotion,face_type,mask,spoofing"
    })

    request_url = request_url + "?access_token=" + ACCESS_TOKEN
    headers = {'content-type': 'application/json'}
    response = requests.post(request_url, data=params, headers=headers)
    if response:
        return response.json()

# %%
import matplotlib.pyplot as plt
import copy
from PIL import ImageDraw
import math

# %% [markdown]
# # 加载学士帽

# %%
HAT_DEMO_PATH_1 = "E:/[Github]/CUCBiye/API/hat_demo_1.png"
HAT_DEMO_PATH_2 = "E:/[Github]/CUCBiye/API/hat_demo_2.png"

# %%
hat_img=Image.open(HAT_DEMO_PATH_2).convert('RGBA')
plt.imshow(hat_img)

# %% [markdown]
# # 人脸检验

# %%
demo_base64 = load_file_in_base64(DEMO_PATH_2)  # 载入目标图
detect_result = face_detect(demo_base64)  # 请求API

# %%
detect_result
# Out:
# {'error_code': 0,
#  'error_msg': 'SUCCESS',
#  'log_id': 2011500165201,
#  'timestamp': 1591846328,
#  'cached': 0,
#  'result': {'face_num': 1,
#   'face_list': [{'face_token': 'b565068b419c75cb0583e0336ef911b0',
#     'location': {'left': 309.4,
#      'top': 143.61,
#      'width': 166,
#      'height': 159,
#      'rotation': 13},
#     'face_probability': 1,
#     'angle': {'yaw': -13.83, 'pitch': 6.54, 'roll': 12.72},
#     'age': 22,
#     'beauty': 84.7,
#     'expression': {'type': 'none', 'probability': 1},
#     'face_shape': {'type': 'oval', 'probability': 0.35},
#     'gender': {'type': 'female', 'probability': 1},
#     'glasses': {'type': 'none', 'probability': 1},
#     'landmark': [{'x': 366.35, 'y': 188.46},
#      {'x': 434.39, 'y': 205.55},
#      {'x': 397.69, 'y': 281.2},
#      {'x': 387.21, 'y': 279.33},
#      {'x': 373.74, 'y': 275.97}],
#     'landmark150': {'cheek_right_1': {'x': 302.5, 'y': 179.23},
#      'cheek_right_3': {'x': 301.25, 'y': 207.41},
#      'cheek_right_5': {'x': 302.17, 'y': 236.42},
#      'cheek_right_7': {'x': 308.56, 'y': 266.41},
#      'cheek_right_9': {'x': 327.2, 'y': 293.81},
#      'cheek_right_11': {'x': 350.07, 'y': 313.7},
#      'chin_2': {'x': 376.02, 'y': 324.59},
#      'cheek_left_11': {'x': 400.81, 'y': 317.69},
#      'cheek_left_9': {'x': 420.98, 'y': 300.52},
#      'cheek_left_7': {'x': 436.38, 'y': 281.11},
#      'cheek_left_5': {'x': 448.38, 'y': 260.7},
#      'cheek_left_3': {'x': 458.05, 'y': 239.71},
#      'cheek_left_1': {'x': 464.25, 'y': 217.98},
#      'eye_right_corner_right': {'x': 348.21, 'y': 186.57},
#      'eye_right_eyelid_upper_2': {'x': 358.56, 'y': 182.35},
#      'eye_right_eyelid_upper_4': {'x': 368.45, 'y': 182.48},
#      'eye_right_eyelid_upper_6': {'x': 377.21, 'y': 187.06},
#      'eye_right_corner_left': {'x': 382.63, 'y': 196.97},
#      'eye_right_eyelid_lower_6': {'x': 374.19, 'y': 196.31},
#      'eye_right_eyelid_lower_4': {'x': 365, 'y': 194.71},
#      'eye_right_eyelid_lower_2': {'x': 356.08, 'y': 191.26},
#      'eye_right_eyeball_center': {'x': 366.72, 'y': 188.26},
#      'eyebrow_right_corner_right': {'x': 338.08, 'y': 164.99},
#      'eyebrow_right_upper_2': {'x': 354.4, 'y': 156.69},
#      'eyebrow_right_upper_3': {'x': 370.43, 'y': 157.51},
#      'eyebrow_right_upper_4': {'x': 384.64, 'y': 162.33},
#      'eyebrow_right_corner_left': {'x': 395.75, 'y': 174.43},
#      'eyebrow_right_lower_3': {'x': 381.9, 'y': 171.25},
#      'eyebrow_right_lower_2': {'x': 368.04, 'y': 167.07},
#      'eyebrow_right_lower_1': {'x': 353.38, 'y': 165.03},
#      'eye_left_corner_right': {'x': 421.33, 'y': 207.68},
#      'eye_left_eyelid_upper_2': {'x': 429.99, 'y': 200.75},
#      'eye_left_eyelid_upper_4': {'x': 439.33, 'y': 200.48},
#      'eye_left_eyelid_upper_6': {'x': 447.05, 'y': 204.5},
#      'eye_left_corner_left': {'x': 451.44, 'y': 212.66},
#      'eye_left_eyelid_lower_6': {'x': 444.94, 'y': 214.16},
#      'eye_left_eyelid_lower_4': {'x': 436.97, 'y': 213.55},
#      'eye_left_eyelid_lower_2': {'x': 428.5, 'y': 210.86},
#      'eye_left_eyeball_center': {'x': 434.85, 'y': 206.17},
#      'eyebrow_left_corner_right': {'x': 425.99, 'y': 183.73},
#      'eyebrow_left_upper_2': {'x': 437.74, 'y': 177.91},
#      'eyebrow_left_upper_3': {'x': 448.73, 'y': 179.25},
#      'mouth_lip_lower_outer_7': {'x': 390.42, 'y': 288.69},
#      'mouth_lip_lower_outer_5': {'x': 380.73, 'y': 286.45},
#      'mouth_lip_lower_outer_4': {'x': 376.07, 'y': 284.53},
#      'mouth_lip_lower_outer_2': {'x': 366.74, 'y': 278.63},
#      'mouth_lip_lower_outer_1': {'x': 362.74, 'y': 275.1},
#      'mouth_lip_upper_inner_1': {'x': 364.36, 'y': 271.27},
#      'mouth_lip_upper_inner_2': {'x': 369.37, 'y': 271.7},
#      'mouth_lip_upper_inner_4': {'x': 379.66, 'y': 273.11},
#      'mouth_lip_upper_inner_5': {'x': 384.2, 'y': 274.27},
#      'mouth_lip_upper_inner_7': {'x': 393.02, 'y': 276.6},
#      'mouth_lip_upper_inner_8': {'x': 396.56, 'y': 277.49},
#      'mouth_lip_upper_inner_10': {'x': 403.68, 'y': 280.3},
#      'mouth_lip_upper_inner_11': {'x': 406.35, 'y': 281.75},
#      'mouth_lip_lower_inner_11': {'x': 405.8, 'y': 283.33},
#      'mouth_lip_lower_inner_10': {'x': 402.93, 'y': 282.23},
#      'mouth_lip_lower_inner_8': {'x': 395.75, 'y': 280.08},
#      'mouth_lip_lower_inner_7': {'x': 392.32, 'y': 279.26},
#      'mouth_lip_lower_inner_5': {'x': 383.57, 'y': 277.15},
#      'mouth_lip_lower_inner_4': {'x': 379.24, 'y': 275.99},
#      'mouth_lip_lower_inner_2': {'x': 369.1, 'y': 273.69},
#      'mouth_lip_lower_inner_1': {'x': 364.17, 'y': 272.81}},
#     'race': {'type': 'yellow', 'probability': 1},
#     'quality': {'occlusion': {'left_eye': 0,
#       'right_eye': 0,
#       'nose': 0,
#       'mouth': 0,
#       'left_cheek': 0.01,
#       'right_cheek': 0,
#       'chin_contour': 0},
#      'blur': 0,
#      'illumination': 173,
#      'completeness': 1},
#     'eye_status': {'left_eye': 0.9999998808, 'right_eye': 1},
#     'emotion': {'type': 'neutral', 'probability': 0.96},
#     'face_type': {'type': 'human', 'probability': 0.99},
#     'mask': {'type': 0, 'probability': 1},
#     'spoofing': 0.0001995002094}]}}

# %%
detect_result["result"]["face_list"][0]["location"]
# Out:
# {'left': 309.4, 'top': 143.61, 'width': 166, 'height': 159, 'rotation': 13}

# %%
point_26 = detect_result["result"]["face_list"][0]["landmark72"][26]
point_26
# Out:
# {'x': 394, 'y': 174.53}

# %%
point_39 = detect_result["result"]["face_list"][0]["landmark72"][39]
point_39
# Out:
# {'x': 425.66, 'y': 183.64}

# %%
point_57 = detect_result["result"]["face_list"][0]["landmark72"][57]
point_57
# Out:
# {'x': 401.59, 'y': 241.92}

# %%
left = round(detect_result["result"]["face_list"][0]["location"]["left"])
top = round(detect_result["result"]["face_list"][0]["location"]["top"])
width = round(detect_result["result"]["face_list"][0]["location"]["width"])
height = round(detect_result["result"]["face_list"][0]["location"]["height"])
rotation = round(detect_result["result"]["face_list"][0]["location"]["rotation"])

# %%
img=Image.open(DEMO_PATH_2)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=700x700 at 0x2C9B0CB0A90>

# %% [markdown]
# ## 脸部边框

# %%
# 左上角点
point_1 = (left,top)
# 右上角点
point_2 = (left+width*math.sin(math.pi*(90-rotation)/180),top+width*math.cos(math.pi*(90-rotation)/180))
# 右下角点
point_3 = (point_2[0]-height*math.cos(math.pi*(90-rotation)/180),point_2[1]+height*math.sin(math.pi*(90-rotation)/180))
# 左下角点
point_4 = (left-height*math.sin(math.pi*rotation/180),top+height*math.cos(math.pi*rotation/180))

# %% [markdown]
# ## 眉心坐标

# %%
eyebrow_point = ((point_26["x"]+point_39["x"])/2,(point_26["y"]+point_39["y"])/2)
eyebrow_point
# Out:
# (409.83000000000004, 179.08499999999998)

# %% [markdown]
# ## 鼻尖坐标

# %%
nose_point = (point_57["x"],point_57["y"])
nose_point
# Out:
# (401.59, 241.92)

# %% [markdown]
# ## 发际线中点

# %%
hair_point = (2*eyebrow_point[0]-1*nose_point[0],2*eyebrow_point[1]-1*nose_point[1])
hair_point
# Out:
# (418.0700000000001, 116.24999999999997)

# %% [markdown]
# ## 标点绘图

# %%
# 画圆方法参考：https://www.jianshu.com/p/cdea3ba63cd7
draw = ImageDraw.Draw(img)
draw.line([point_1,point_2,point_3,point_4,point_1],width=4,fill='red')
draw.ellipse((eyebrow_point[0]-5,eyebrow_point[1]-5,eyebrow_point[0]+5,eyebrow_point[1]+5),fill="blue")
draw.ellipse((nose_point[0]-5,nose_point[1]-5,nose_point[0]+5,nose_point[1]+5),fill="blue")
draw.ellipse((hair_point[0]-5,hair_point[1]-5,hair_point[0]+5,hair_point[1]+5),fill="green")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=700x700 at 0x2C9B0CB0A90>

# %% [markdown]
# # 学士帽处理

# %%
hat_change = copy.deepcopy(hat_img)

# %%
hat_img.size
big_size = 1.2
hat_actual_width = 93

# %%
hat_width = int(big_size*width/hat_actual_width*hat_img.size[0])
hat_height = int(hat_width/hat_img.size[0]*hat_img.size[1])
hat_width,hat_height
# Out:
# (406, 354)

# %%
# 缩放参考方法：https://blog.csdn.net/wsl985/article/details/90319943
hat_change = hat_change.resize((hat_width,hat_height),Image.ANTIALIAS)
hat_change
# Out:
# <PIL.Image.Image image mode=RGBA size=406x354 at 0x2C9ADEC68B0>

# %%
hat_change.size
# Out:
# (406, 354)

# %%
# 旋转参考方法：https://www.cnblogs.com/brainstorming/p/7651506.html
hat_rotate = hat_change.rotate(-rotation,expand=True)
hat_rotate
# Out:
# <PIL.Image.Image image mode=RGBA size=476x438 at 0x2C9ADE45520>

# %%
hat_rotate.size
# Out:
# (476, 438)

# %% [markdown]
# # 戴帽子

# %%
hat_left = int(hair_point[0]-hat_rotate.size[0]/2)
hat_top = int(hair_point[1]-hat_rotate.size[1]/2)

# %%
merge_img = copy.deepcopy(img)

# %%
# 图片粘贴方法参考：https://blog.csdn.net/haeasringnar/article/details/103895140
# PNG透明方法参考：https://www.jianshu.com/p/8ea7f1057875
merge_img.paste(hat_rotate, (hat_left, hat_top), hat_rotate)
merge_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=700x700 at 0x2C9ADECB8B0>

# %% [markdown]
# # 人体关键点坐标

# %%
def body_analysis(demo_base64):
    """
    人脸监测和属性分析
    :param demo_base64: <str> BASE64格式的目标图
    :return:
    """
    request_url = "https://aip.baidubce.com/rest/2.0/image-classify/v1/body_analysis"

    params = {"image": demo_base64}

    request_url = request_url + "?access_token=" + ACCESS_TOKEN_2
    headers = {'content-type': 'application/x-www-form-urlencoded'}
    response = requests.post(request_url, data=params, headers=headers)
    if response:
        return response.json()

# %%
body_result = body_analysis(demo_base64)  # 请求API

# %%
body_result["person_info"][0]["body_parts"]
# Out:
# {'left_hip': {'y': 694.48828125,
#   'x': 418.45703125,
#   'score': 0.09058690071105957},
#  'top_head': {'y': 75.73828125,
#   'x': 412.01171875,
#   'score': 0.7968325614929199},
#  'right_mouth_corner': {'y': 281.98828125,
#   'x': 354.00390625,
#   'score': 0.9079938530921936},
#  'neck': {'y': 346.44140625, 'x': 334.66796875, 'score': 0.7694234848022461},
#  'left_shoulder': {'y': 417.33984375,
#   'x': 463.57421875,
#   'score': 0.7448326945304871},
#  'left_knee': {'y': 662.26171875,
#   'x': 495.80078125,
#   'score': 0.0316317081451416},
#  'left_ankle': {'y': 655.81640625,
#   'x': 399.12109375,
#   'score': 0.02697796002030373},
#  'left_mouth_corner': {'y': 269.09765625,
#   'x': 412.01171875,
#   'score': 0.8744943737983704},
#  'right_elbow': {'y': 681.59765625,
#   'x': 154.19921875,
#   'score': 0.6252638697624207},
#  'right_ear': {'y': 198.19921875,
#   'x': 289.55078125,
#   'score': 0.8250755071640015},
#  'nose': {'y': 243.31640625, 'x': 399.12109375, 'score': 0.8931615352630615},
#  'left_eye': {'y': 191.75390625,
#   'x': 437.79296875,
#   'score': 0.8668239712715149},
#  'right_eye': {'y': 198.19921875,
#   'x': 366.89453125,
#   'score': 0.8939784169197083},
#  'right_hip': {'y': 681.59765625,
#   'x': 250.87890625,
#   'score': 0.1412173807621002},
#  'left_wrist': {'y': 572.02734375,
#   'x': 476.46484375,
#   'score': 0.08384956419467926},
#  'left_ear': {'y': 230.42578125,
#   'x': 463.57421875,
#   'score': 0.8199772834777832},
#  'left_elbow': {'y': 681.59765625,
#   'x': 508.69140625,
#   'score': 0.6016896963119507},
#  'right_shoulder': {'y': 430.23046875,
#   'x': 167.08984375,
#   'score': 0.6538547277450562},
#  'right_ankle': {'y': 655.81640625,
#   'x': 347.55859375,
#   'score': 0.090664342045784},
#  'right_knee': {'y': 675.15234375,
#   'x': 308.88671875,
#   'score': 0.06176714599132538},
#  'right_wrist': {'y': 700, 'x': 295.99609375, 'score': 0.0577973835170269}}

# %%
draw_2 = ImageDraw.Draw(img)
for name,value in body_result["person_info"][0]["body_parts"].items():
    if value["score"]>0.5:
        draw_2.ellipse((value["x"]-5,value["y"]-5,value["x"]+5,value["y"]+5),fill="purple")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=700x700 at 0x2C9B0CB0A90>
